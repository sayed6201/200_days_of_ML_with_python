# %%
import pandas as pd

# %%
datafram = pd.read_csv('titanic_train.csv')

# %% [markdown]
# ## Darafram Creation

# %%
#load builtin dataset
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
#create datafram from arrays
create_df = pd.DataFrame(data=cancer['data'],columns=cancer['feature_names'])
df_target = pd.DataFrame(cancer['target'],columns=['Cancer'])
create_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
datafram.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
datafram[['PassengerId', 'Survived']].head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
# : -> All . :-1 -> all exceot last column
datafram.iloc[:, :-1].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin
# 0      0         A/5 21171   7.2500   NaN
# 1      0          PC 17599  71.2833   C85
# 2      0  STON/O2. 3101282   7.9250   NaN
# 3      0            113803  53.1000  C123
# 4      0            373450   8.0500   NaN

# %%
datafram['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
datafram.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %% [markdown]
# #### Datafram value update

# %%
data = pd.read_csv("College_Data")

# data[data['Unnamed: 0'] == 'Cazenovia College']['Grad.Rate'] = 100 #You can only acess, can't update

# selecting data 
# Boolean indexing (df[df['col'] == value] )
# Positional indexing (df.iloc[...])
# Label indexing (df.xs(...))
# df.query(...) API

data.loc[95,'Grad.Rate'] = 100 #you can change the value with .loc(row_index,column_name)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Customized funtion: Using average in NULL value

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:
            return 29

        else:
            return 24

    else:
        return Age

# %%
train = datafram
train['Age'] = train[['Age','Pclass']].apply(impute_age,axis=1)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Caregorical values to numerical representation

# %%
#creating dummy vars for sex and embark
sex = pd.get_dummies(datafram['Sex'],drop_first=True)
embark = pd.get_dummies(datafram['Embarked'],drop_first=True)

#removing sex and embark columns
new_dataframe = datafram.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=False)

#adding new sex and embark columns
new_dataframe = pd.concat([new_dataframe, sex, embark], axis=1)

new_dataframe.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin  male  Q  \
# 0            1         0       3  22.0      1      0   7.2500   NaN     1  0
# 1            2         1       1  38.0      1      0  71.2833   C85     0  0
# 2            3         1       3  26.0      0      0   7.9250   NaN     0  0
# 3            4         1       1  35.0      1      0  53.1000  C123     0  0
# 4            5         0       3  35.0      0      0   8.0500   NaN     1  0
#
#    S
# 0  1
# 1  0
# 2  1
# 3  1
# 4  1

# %%
# Ordinal categorical representation

from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
array_target = LE.fit_transform(iris['species'])

df_target = pd.DataFrame(data=array_target, columns=['target_code'])

# %% [markdown]
# ### Standardize the Variables or scaling features

# %% [markdown]
# Because the KNN classifier predicts the class of a given test observation by identifying the observations that are nearest to it, the scale of the variables matters. Any variables that are on a large scale will have a much larger effect on the distance between the observations, and hence on the KNN classifier, than variables that are on a small scale.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df.drop('TARGET CLASS',axis=1))
scaled_features = scaler.transform(df.drop('TARGET CLASS',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
